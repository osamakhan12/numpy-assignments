# %% [markdown]
# # IMAGE ASSIGNEMNT SIR ANEES

# %%
import os
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt 
from PIL import Image,ImageOps
import numpy as np
import glob

# %%
#n=np.array([16,200,200,3])
path=os.listdir('images/')

# %%
for rootdir,subrootdir,files in os.walk('images/'):
    print("root directory\n",rootdir)
    print("sub root directory\n",subrootdir)
    print("files in folder\n",files)
    print("end")
# Out:
# root directory
#  images/
# sub root directory
#  []
# files in folder
#  ['11.jpg', 'photo2.jpg', 'photo3.jpg', 'pic1.jpg', 'pic2.jpg', 'pic3.jpg', 'pic4.jpeg', 'pic5.jpg', 'pic6.jpg', 'pic7.jpg', 'pic8.jpg', 'pict1.png', 'pict2.png', 'pict3.png']
# end

# %%
path=glob.glob('images/*.jpg')

# %%
main=[]
for ims in path:
    i=Image.open(ims)
    #i=Image.open(path)
    a=i.resize((200,200))
    n=np.array(a)
    main.append(n)
    np.savez("x_array",main)
    print(main)
    a.size
    a
# Out:
# [array([[[226, 229, 210],
#         [228, 231, 212],
#         [230, 233, 216],
#         ...,
#         [ 82,  71,  43],
#         [ 78,  69,  40],
#         [ 78,  69,  40]],
#
#        [[227, 230, 211],
#         [229, 232, 215],
#         [231, 234, 217],
#         ...,
#         [ 82,  71,  43],
#         [ 76,  69,  40],
#         [ 76,  69,  40]],
#
#        [[229, 231, 217],
#         [230, 232, 218],
#         [232, 234, 220],
#         ...,
#         [ 80,  71,  42],
#         [ 76,  69,  40],
#         [ 76,  69,  40]],
#
#        ...,
#
#        [[200, 198, 201],
#         [203, 200, 193],
#         [203, 200, 185],
#         ...,
#         [ 61,  49,  11],
#         [ 58,  41,  13],
#         [ 58,  41,  13]],
#
#        [[200, 199, 197],
#         [200, 196, 185],
#         [200, 195, 176],
#         ...,
#         [ 60,  48,  10],
#         [ 57,  40,  12],
#         [ 57,  40,  12]],
#
#        [[200, 197, 192],
#         [197, 193, 181],
#         [196, 189, 170],
# ...

# %%
nn=np.load("x_array.npz")
print(nn)

# %%
im = Image.open('E:\python\images/pic1.jpg')
width, height = im.size
print(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=866x1300 at 0x18D1967DAC8>

# %% [markdown]
# #  IMAGE ASSIGNMENT SIR SHAHZAD

# %%
def check():
    fname=input('enter name of file')
    try:
        i=os.listdir(fname)
    except:
        print('files not found')
    else:    
        img_dir=glob.glob('images/*.jpg')
        c=0
        for i in img_dir:
            c+=1
            print(i)
        print('number of files',c)
check()
# Out:
# enter name of filephotos/
# images\11.jpg
# images\photo2.jpg
# images\photo3.jpg
# images\pic1.jpg
# images\pic2.jpg
# images\pic3.jpg
# images\pic5.jpg
# images\pic6.jpg
# images\pic7.jpg
# images\pic8.jpg
# number of files 10

# %%
def resize():
    n=np.array([10,200,200,3])
    for ims in img_dir:
        i=Image.open(ims)
    #i=Image.open(path)
        a=i.resize((200,200))
        n=a
        print(n)
        print("*"*25)
resize()
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D163F0348>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D19600548>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D163F0348>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D19600D48>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D163F0348>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D19600F48>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D163F0348>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D19600608>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D195FA788>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D19600EC8>
# *************************

# %%
def main():
    check()
    resize()
    a=np.array(main)
    return a

# %%
if __name__ == "__main__":
    a=main()
    a.
# Out:
# enter name of fileimages/
# images\11.jpg
# images\photo2.jpg
# images\photo3.jpg
# images\pic1.jpg
# images\pic2.jpg
# images\pic3.jpg
# images\pic5.jpg
# images\pic6.jpg
# images\pic7.jpg
# images\pic8.jpg
# number of files 10
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D1921C488>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D1965F6C8>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D1967D748>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D1921C488>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D1967D748>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D1921C488>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D1967D748>
# *************************
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18D1967DF48>
# *************************
# ...

# %%
'''from PIL import Image
import numpy as np

w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[0:256, 0:256] = [255, 0, 0] # red patch in upper left
img = Image.fromarray(data, 'RGB')
img.save('my.png')
img.show()
'''
